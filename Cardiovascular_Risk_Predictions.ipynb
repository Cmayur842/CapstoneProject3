# %% [markdown]
# <a href="https://colab.research.google.com/github/Cmayur842/CapstoneProject3/blob/main/Cardiovascular_Risk_Predictions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Title : Cardio-Vascular Risk Prediction(On Classification)**

# %% [markdown]
# List of Attributes Cantaints inside the dataset: . Problem statement . Importing the libraries and the dataset . Mounting my Drive . Understand the data . Variable Description . Data cleaning . Handling missing data . Exploratory data analysis . Feature selection . Data preprocessing . ML model implementation . Results . Summary and conclusions . References

# %% [markdown]
# # 1. Statement:
# Cardiovascular diseases (CVDs) are the major cause of mortality worldwide.
#
# *  According to WHO, 17.9 million people died from CVDs in 2019, accounting for 32% of all global fatalities.
# *   Though CVDs cannot be treated, predicting the risk of the disease and taking the necessary precautions and medications can help to avoid severe symptoms and, in some cases, even death.
#
#
# *   As a result, it is critical that we accurately predict the risk of heart disease in order to avert as many fatalities as possible.

# %% [markdown]
# # 2. Importing the Required libraries and the Mounting dataset:**bold text**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.impute import KNNImputer
from sklearn.feature_selection import chi2
from sklearn.metrics import recall_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **3. Mounting My Drive:**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = "/content/drive/MyDrive/EDA CAPSTONE PROJECT 3/data_cardiovascular_risk.csv"
CRP_df=pd.read_csv(path)

# %% [markdown]
# # **4. Understand the Data**

# %%
# First 5 rows of the dataset 
CRP_df.head(5)
# Out:
#    id  age  education sex is_smoking  cigsPerDay  BPMeds  prevalentStroke  \
# 0   0   64        2.0   F        YES         3.0     0.0                0
# 1   1   36        4.0   M         NO         0.0     0.0                0
# 2   2   46        1.0   F        YES        10.0     0.0                0
# 3   3   50        1.0   M        YES        20.0     0.0                0
# 4   4   64        1.0   F        YES        30.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    221.0  148.0   85.0    NaN       90.0     80.0
# 1             1         0    212.0  168.0   98.0  29.77       72.0     75.0
# 2             0         0    250.0  116.0   71.0  20.35       88.0     94.0
# 3             1         0    233.0  158.0   88.0  28.26       68.0     94.0
# 4             0         0    241.0  136.5   85.0  26.42       70.0     77.0
#
#    TenYearCHD
# 0           1
# 1           0
# 2           0
# 3           1
# 4           0

# %%
# Last 5 rows of the dataset 
CRP_df.tail(5)
# Out:
#         id  age  education sex is_smoking  cigsPerDay  BPMeds  \
# 3385  3385   60        1.0   F         NO         0.0     0.0
# 3386  3386   46        1.0   F         NO         0.0     0.0
# 3387  3387   44        3.0   M        YES         3.0     0.0
# 3388  3388   60        1.0   M         NO         0.0     NaN
# 3389  3389   54        3.0   F         NO         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 3385                0             0         0    261.0  123.5   79.0  29.28
# 3386                0             0         0    199.0  102.0   56.0  21.96
# 3387                0             1         0    352.0  164.0  119.0  28.92
# 3388                0             1         0    191.0  167.0  105.0  23.01
# 3389                0             0         0    288.0  124.0   77.0  29.88
#
#       heartRate  glucose  TenYearCHD
# 3385       70.0    103.0           0
# 3386       80.0     84.0           0
# 3387       73.0     72.0           1
# 3388       80.0     85.0           0
# 3389       79.0     92.0           0

# %%
# Dataset Rows & Columns 
CRP_df.shape
# Out:
# (3390, 17)

# %%
# Dataset Info
CRP_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3390 non-null   int64
#  1   age              3390 non-null   int64
#  2   education        3303 non-null   float64
#  3   sex              3390 non-null   object
#  4   is_smoking       3390 non-null   object
#  5   cigsPerDay       3368 non-null   float64
#  6   BPMeds           3346 non-null   float64
#  7   prevalentStroke  3390 non-null   int64
#  8   prevalentHyp     3390 non-null   int64
#  9   diabetes         3390 non-null   int64
#  10  totChol          3352 non-null   float64
#  11  sysBP            3390 non-null   float64
#  12  diaBP            3390 non-null   float64
#  13  BMI              3376 non-null   float64
#  14  heartRate        3389 non-null   float64
#  15  glucose          3086 non-null   float64
#  16  TenYearCHD       3390 non-null   int64
# dtypes: float64(9), int64(6), object(2)
# memory usage: 450.4+ KB

# %% [markdown]
# # **5.Variable Description:**

# %% [markdown]
# Demographic:
#
#
# *   Sex: male or female ("M" or "F")
# *   Age: Age of the patient (Continuous - Although the recorded ages have been truncated to whole numbers, the concept of age is continuous
# *   Education: The level of education of the patient (categorical values - 1,2,3,4)
#
# Behavioral:
#
# *   is_smoking: whether or not the patient is a current smoker ("YES" or "NO")
#
# *   Cigs Per Day: the number of cigarettes that the person smoked on average in one day.(can be considered continuous as one can have any number of cigarettes, even half a cigarette.)
#
# Medical (history):
#
# *   BP Meds: whether or not the patient was on blood pressure medication (Nominal)
# *   Prevalent Stroke: whether or not the patient had previously had a stroke (Nominal)
# *  Prevalent Hyp: whether or not the patient was hypertensive (Nominal)
# *   Prevalent Stroke: whether or not the patient had previously had a stroke (Nominal)
#
# Medical (current):
#
# *   Tot Chol: total cholesterol level (Continuous)
# *   Sys BP: systolic blood pressure (Continuous)
# *   Dia BP: diastolic blood pressure (Continuous)
# *   BMI: Body Mass Index (Continuous)
# *   Heart Rate: heart rate (Continuous - In medical research, variables such as heart rate though in fact discrete, yet are considered continuous because of large number of possible values.)
# *   Glucose: glucose level (Continuous)

# %% [markdown]
# **Predict variable (desired target):**
#
# *   L10-year risk of coronary heart disease CHD(binary: “1”, means “Yes”, “0” means “No”)

# %%
#Checking the Duplicates:
CRP_df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3385    False
# 3386    False
# 3387    False
# 3388    False
# 3389    False
# Length: 3390, dtype: bool

# %%
# checking null values
CRP_df.isna().sum().sum()
# Out:
# 510

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
plt.figure(figsize=(10,5))
sns.heatmap(CRP_df.isnull(), cbar=False)
# Out:
# <Axes: >

# %% [markdown]
# **The dataset contains 3390 rows and 17 columns. There are no duplicate records, and contains 510 missing values.**

# %% [markdown]
# # **6. Data Cleansing:**

# %%
# Dataset Columns
CRP_df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
# Dataset Describe
CRP_df.describe(include='all')
# Out:
#                  id          age    education   sex is_smoking   cigsPerDay  \
# count   3390.000000  3390.000000  3303.000000  3390       3390  3368.000000
# unique          NaN          NaN          NaN     2          2          NaN
# top             NaN          NaN          NaN     F         NO          NaN
# freq            NaN          NaN          NaN  1923       1703          NaN
# mean    1694.500000    49.542183     1.970936   NaN        NaN     9.069477
# std      978.753033     8.592878     1.019081   NaN        NaN    11.879078
# min        0.000000    32.000000     1.000000   NaN        NaN     0.000000
# 25%      847.250000    42.000000     1.000000   NaN        NaN     0.000000
# 50%     1694.500000    49.000000     2.000000   NaN        NaN     0.000000
# 75%     2541.750000    56.000000     3.000000   NaN        NaN    20.000000
# max     3389.000000    70.000000     4.000000   NaN        NaN    70.000000
#
#              BPMeds  prevalentStroke  prevalentHyp     diabetes      totChol  \
# count   3346.000000      3390.000000   3390.000000  3390.000000  3352.000000
# unique          NaN              NaN           NaN          NaN          NaN
# top             NaN              NaN           NaN          NaN          NaN
# freq            NaN              NaN           NaN          NaN          NaN
# mean       0.029886         0.006490      0.315339     0.025664   237.074284
# std        0.170299         0.080309      0.464719     0.158153    45.247430
# min        0.000000         0.000000      0.000000     0.000000   107.000000
# 25%        0.000000         0.000000      0.000000     0.000000   206.000000
# 50%        0.000000         0.000000      0.000000     0.000000   234.000000
# 75%        0.000000         0.000000      1.000000     0.000000   264.000000
# max        1.000000         1.000000      1.000000     1.000000   696.000000
#
#              sysBP        diaBP          BMI    heartRate      glucose  \
# count   3390.00000  3390.000000  3376.000000  3389.000000  3086.000000
# unique         NaN          NaN          NaN          NaN          NaN
# top            NaN          NaN          NaN          NaN          NaN
# freq           NaN          NaN          NaN          NaN          NaN
# mean     132.60118    82.883038    25.794964    75.977279    82.086520
# std       22.29203    12.023581     4.115449    11.971868    24.244753
# min       83.50000    48.000000    15.960000    45.000000    40.000000
# 25%      117.00000    74.500000    23.020000    68.000000    71.000000
# 50%      128.50000    82.000000    25.380000    75.000000    78.000000
# 75%      144.00000    90.000000    28.040000    83.000000    87.000000
# max      295.00000   142.500000    56.800000   143.000000   394.000000
#
#          TenYearCHD
# count   3390.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean       0.150737
# std        0.357846
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
# Renaming the columns
CRP_df.rename(columns={'cigsPerDay':'cigs_per_day','BPMeds':'bp_meds',
                   'prevalentStroke':'prevalent_stroke','prevalentHyp':'prevalent_hyp',
                   'totChol':'total_cholesterol','sysBP':'systolic_bp','diaBP':'diastolic_bp',
                   'BMI':'bmi','heartRate':'heart_rate','TenYearCHD':'ten_year_chd'},
          inplace = True)

# %%
# Check Unique Values for each variable.
for i in CRP_df.columns.tolist():
  print("Unique values in",i,":",CRP_df[i].nunique())
# Out:
# Unique values in id : 3390
# Unique values in age : 39
# Unique values in education : 4
# Unique values in sex : 2
# Unique values in is_smoking : 2
# Unique values in cigs_per_day : 32
# Unique values in bp_meds : 2
# Unique values in prevalent_stroke : 2
# Unique values in prevalent_hyp : 2
# Unique values in diabetes : 2
# Unique values in total_cholesterol : 240
# Unique values in systolic_bp : 226
# Unique values in diastolic_bp : 142
# Unique values in bmi : 1259
# Unique values in heart_rate : 68
# Unique values in glucose : 132
# Unique values in ten_year_chd : 2

# %%
# Defining 3 lists containing the column names of 
# a. dependent variables
# b. continuous independent variables
# c. categorical independent variables
# This is defined based on the number of unique values for each attribute

dependent_var = ['ten_year_chd']
continuous_var = ['age','cigs_per_day','total_cholesterol','systolic_bp', 'diastolic_bp', 'bmi', 'heart_rate', 'glucose']
categorical_var = ['education', 'sex', 'is_smoking','bp_meds','prevalent_stroke', 'prevalent_hyp', 'diabetes']

# %%
# Encoding the binary columns

CRP_df['sex'] = np.where(CRP_df['sex'] == 'M',1,0)
CRP_df['is_smoking'] = np.where(CRP_df['is_smoking'] == 'YES',1,0)

# %% [markdown]
# # **7. Handling missing data:**

# %%
# checking for null values
CRP_df.isna().sum()
# Out:
# id                     0
# age                    0
# education             87
# sex                    0
# is_smoking             0
# cigs_per_day          22
# bp_meds               44
# prevalent_stroke       0
# prevalent_hyp          0
# diabetes               0
# total_cholesterol     38
# systolic_bp            0
# diastolic_bp           0
# bmi                   14
# heart_rate             1
# glucose              304
# ten_year_chd           0
# dtype: int64

# %%
# total null values
CRP_df.isna().sum().sum()
# Out:
# 510

# %% [markdown]
# **There are a total of 510 missing values in the dataset.**

# %% [markdown]
# ## **8.1. Replacing the missing values in the categorical columns with the most frequent entry:**

# %%
# Replacing the missing values in the categorical columns with its mode
CRP_df['education'] = CRP_df['education'].fillna(CRP_df['education'].mode()[0])
CRP_df['bp_meds'] = CRP_df['bp_meds'].fillna(CRP_df['bp_meds'].mode()[0])

# %%
# education distribution after mode imputation
CRP_df.education.value_counts()
# Out:
# 1.0    1478
# 2.0     990
# 3.0     549
# 4.0     373
# Name: education, dtype: int64

# %%
# bp_meds distribution after mode imputation
CRP_df.bp_meds.value_counts()
# Out:
# 0.0    3290
# 1.0     100
# Name: bp_meds, dtype: int64

# %% [markdown]
# # **8.2. cigs_per_day:**

# %%
# Mean and median number of cigarettes per day
CRP_df.cigs_per_day.mean().round(0),CRP_df.cigs_per_day.median()
# Out:
# (9.0, 0.0)

# %%
# All missing values in the cigs_per_day column
CRP_df[CRP_df['cigs_per_day'].isna()]
# Out:
#         id  age  education  sex  is_smoking  cigs_per_day  bp_meds  \
# 422    422   55        1.0    0           1           NaN      0.0
# 466    466   45        3.0    1           1           NaN      0.0
# 469    469   42        1.0    1           1           NaN      0.0
# 491    491   61        1.0    0           1           NaN      0.0
# 538    538   41        1.0    0           1           NaN      0.0
# 767    767   54        1.0    1           1           NaN      0.0
# 1461  1461   47        2.0    0           1           NaN      0.0
# 1467  1467   49        1.0    0           1           NaN      0.0
# 1597  1597   57        1.0    0           1           NaN      0.0
# 1986  1986   49        2.0    0           1           NaN      0.0
# 2031  2031   58        4.0    0           1           NaN      0.0
# 2087  2087   49        4.0    1           1           NaN      0.0
# 2240  2240   47        3.0    0           1           NaN      0.0
# 2284  2284   45        2.0    1           1           NaN      0.0
# 2527  2527   58        2.0    1           1           NaN      0.0
# 2638  2638   57        1.0    1           1           NaN      0.0
# 2648  2648   39        2.0    1           1           NaN      0.0
# 2723  2723   43        4.0    1           1           NaN      0.0
# 2879  2879   42        1.0    1           1           NaN      0.0
# 2945  2945   53        2.0    1           1           NaN      0.0
# 3301  3301   55        1.0    1           1           NaN      0.0
# 3378  3378   39        3.0    0           1           NaN      0.0
#
#       prevalent_stroke  prevalent_hyp  diabetes  total_cholesterol  \
# 422                  0              1         0              213.0
# 466                  0              1         0              170.0
# 469                  0              0         0              196.0
# 491                  0              1         0              356.0
# 538                  0              0         0              171.0
# 767                  0              0         0              219.0
# 1461                 0              0         0              365.0
# 1467                 0              0         0              252.0
# 1597                 0              0         0              229.0
# 1986                 0              1         0              233.0
# 2031                 0              1         0              270.0
# 2087                 0              0         0              256.0
# 2240                 0              0         0              321.0
# 2284                 0              0         0              248.0
# 2527                 0              0         0              235.0
# 2638                 0              0         0              223.0
# 2648                 0              0         0              285.0
# 2723                 0              0         0              222.0
# 2879                 0              0         0              226.0
# 2945                 0              0         0              276.0
# 3301                 0              0         0              214.0
# 3378                 0              0         0              197.0
#
#       systolic_bp  diastolic_bp    bmi  heart_rate  glucose  ten_year_chd
# 422         163.0          91.0  28.66        69.0     66.0             0
# 466         145.5          99.0  26.74        83.0     85.0             0
# 469         123.0          73.0  22.06        66.0      NaN             0
# 491         168.0          98.0  27.30       103.0    106.0             0
# 538         135.0          82.5  24.35        79.0     82.0             0
# 767         110.0          72.0  26.05        95.0     86.0             0
# 1461        127.0          76.0  24.44        72.0     80.0             0
# 1467        123.0          69.0  21.45        72.0     89.0             0
# 1597        115.0          69.0  24.43        80.0     93.0             0
# 1986        158.0         102.0  25.31        90.0     72.0             0
# 2031        195.0         117.5  23.35        75.0      NaN             0
# 2087        127.5          81.5  28.21        93.0     85.0             1
# 2240        132.0          88.0  28.14        90.0     74.0             0
# 2284        121.0          72.0  27.88        64.0     88.0             0
# 2527        127.5          76.0  21.02        81.0    135.0             0
# 2638        107.5          72.5  24.74        62.0    103.0             0
# 2648        121.0          82.0  27.62        85.0     65.0             0
# 2723        109.5          69.0  25.50        75.0      NaN             0
# 2879        119.0          80.0  25.29        62.0     98.0             0
# 2945        130.0          86.0  24.21        58.0     82.0             0
# 3301        132.5          85.5  29.25        70.0    103.0             0
# 3378        126.5          76.5  19.71        55.0     63.0             0

# %% [markdown]
# **From the above table, we find that for every instance of missing values in cigs per day, the patients reported that they smoke.**
#
# Let's check the mean and median number of cigarettes smoked by patients, who reported that they smoke.

# %%
# mean and median number of cigarettes per day for a smoker (excluding non-smokers)
CRP_df[CRP_df['is_smoking']==1]['cigs_per_day'].mean(),CRP_df[CRP_df['is_smoking']==1]['cigs_per_day'].median()
# Out:
# (18.345945945945946, 20.0)

# %%
# distribution of number of cigarettes per day for smokers (excluding non-smokers)
plt.figure(figsize=(10,5))
sns.distplot(CRP_df[CRP_df['is_smoking']==1]['cigs_per_day'])
plt.axvline(CRP_df[CRP_df['is_smoking']==1]['cigs_per_day'].mean(), color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(CRP_df[CRP_df['is_smoking']==1]['cigs_per_day'].median(), color='Black', linestyle='dashed', linewidth=2)
plt.title('Cigs_per_day for smokers distribution')
plt.show()

# %%
# box plot for the number of cigarettes per day for smokers (excluding non-smokers)
plt.figure(figsize=(10,5))
sns.boxplot(CRP_df[CRP_df['is_smoking']==1]['cigs_per_day'])
# Out:
# <Axes: >

# %% [markdown]
# **Since the number of cigarettes smoked by the patients who smoke contains outliers, the missing values in ths cigs_per_day column can be imputed with its median value.**

# %%
# Imputing the missing values in the cigs_per_day 
CRP_df['cigs_per_day'] = CRP_df['cigs_per_day'].fillna(CRP_df[CRP_df['is_smoking']==1]['cigs_per_day'].median())

# %%
# Checking for any wrong entries where the patient is not a smoker
# and cigarettes per day above 0

CRP_df[(CRP_df['is_smoking']==0) & (CRP_df['cigs_per_day']>0)]
# Out:
# Empty DataFrame
# Columns: [id, age, education, sex, is_smoking, cigs_per_day, bp_meds, prevalent_stroke, prevalent_hyp, diabetes, total_cholesterol, systolic_bp, diastolic_bp, bmi, heart_rate, glucose, ten_year_chd]
# Index: []

# %%
# Checking for any wrong entries where the patient is a smoker
# and cigarettes per day is 0

CRP_df[(CRP_df['is_smoking']==1) & (CRP_df['cigs_per_day']==0)]
# Out:
# Empty DataFrame
# Columns: [id, age, education, sex, is_smoking, cigs_per_day, bp_meds, prevalent_stroke, prevalent_hyp, diabetes, total_cholesterol, systolic_bp, diastolic_bp, bmi, heart_rate, glucose, ten_year_chd]
# Index: []

# %%
# Checking for any wrong entries where the patient is a smoker
# and cigarettes per day is 0

CRP_df[(CRP_df['is_smoking']==1) & (CRP_df['cigs_per_day']==0)]
# Out:
# Empty DataFrame
# Columns: [id, age, education, sex, is_smoking, cigs_per_day, bp_meds, prevalent_stroke, prevalent_hyp, diabetes, total_cholesterol, systolic_bp, diastolic_bp, bmi, heart_rate, glucose, ten_year_chd]
# Index: []

# %% [markdown]
# There are no errors in these columns.

# %% [markdown]
# # 8.3. total_cholestrol, bmi, heart_rate:

# %%
# Checking the distribution of the total_cholesterol, bmi, and heart_rate
for i in ['total_cholesterol','bmi','heart_rate']:
  plt.figure(figsize=(10,4))
  sns.distplot(CRP_df[i])
  plt.axvline(CRP_df[i].mean(), color='cyan', linestyle='dashed', linewidth=2)
  plt.axvline(CRP_df[i].median(), color='black', linestyle='dashed', linewidth=2)
  plt.title(i+' distribution')
  plt.show()

# %% [markdown]
# The total_cholestrol, bmi, and heart_rate columns are positively **skewed**

# %%
# Checking outliers in total_cholesterol, bmi, heart_rate columns
for i in ['total_cholesterol','bmi','heart_rate']:
  plt.figure(figsize=(8,8))
  sns.boxplot(CRP_df[i])
  plt.title(i+' boxplot')
  plt.show()

# %% [markdown]
# **The total_cholestrol, bmi, and heart_rate columns contain outliers.**

# %%
# Mean and median for total_cholesterol
CRP_df.total_cholesterol.mean(),CRP_df.total_cholesterol.median()
# Out:
# (237.07428400954655, 234.0)

# %%
# Mean and median for bmi
CRP_df.bmi.mean(),CRP_df.bmi.median()
# Out:
# (25.7949644549763, 25.38)

# %%
# Mean and median for heart_rate
CRP_df.heart_rate.mean(),CRP_df.heart_rate.median()
# Out:
# (75.97727943346119, 75.0)

# %% [markdown]
# Since the total_cholestrol, bmi, and heart_rate columns are positively skewed, and also contains outliers. We can impute the missing values with its median.**bold text**

# %%
# Imputing missing values in the total_cholesterol, bmi, and heart_rate with their medain values
CRP_df['total_cholesterol'] = CRP_df['total_cholesterol'].fillna(CRP_df['total_cholesterol'].median())
CRP_df['bmi'] = CRP_df['bmi'].fillna(CRP_df['bmi'].median())
CRP_df['heart_rate'] = CRP_df['heart_rate'].fillna(CRP_df['heart_rate'].median())

# %%
# mean and median of total_cholesterol after median imputation
CRP_df.total_cholesterol.mean(),CRP_df.total_cholesterol.median()
# Out:
# (237.03982300884957, 234.0)

# %%
# mean and median of bmi after median imputation
CRP_df.bmi.mean(),CRP_df.bmi.median()
# Out:
# (25.793250737463126, 25.38)

# %%
# mean and median of heart_rate after median imputation
CRP_df.heart_rate.mean(),CRP_df.heart_rate.median()
# Out:
# (75.97699115044247, 75.0)

# %% [markdown]
# # 8.4. glucose:**bold text**

# %%
# total missing values in glucose
CRP_df.glucose.isna().sum()
# Out:
# 304

# %% [markdown]
# **The glucose column contains 304 missing values.**

# %%
# distribution of glucose
plt.figure(figsize=(8,5))
sns.distplot(CRP_df['glucose'])
plt.axvline(CRP_df['glucose'].mean(), color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(CRP_df['glucose'].median(), color='black', linestyle='dashed', linewidth=2)
plt.title('Glucose distribution')
plt.show()

# %% [markdown]
# The glucose column is positively **skewed.**

# %%
# Outliers in glucose
plt.figure(figsize=(10,5))
sns.boxplot(CRP_df['glucose'])
plt.title('Glucose boxplot')
# Out:
# Text(0.5, 1.0, 'Glucose boxplot')

# %% [markdown]
# **The glucose column contains outliers.**

# %%
# Mean, median, and mode for glucose
CRP_df.glucose.mean(),CRP_df.glucose.median(),CRP_df.glucose.mode()
# Out:
# (82.08651976668827,
#  78.0,
#  0    75.0
#  Name: glucose, dtype: float64)

# %% [markdown]
# *   The distribution is positively skewed, with outliers.
# There are 304 missing values in the glucose column.
#
# *   There are 304 missing values in the glucose column. If we choose to impute them with a single value of mean / median, we will be adding high bias at that point.
# *   To avoid this we can impute the missing values using KNN imputer.
# *   If the dataset in question had been a time series, we could have used the interpolation method to impute the missing values.

# %%
# Using KNN imputer with K=10
imputer = KNNImputer(n_neighbors=10)
imputed = imputer.fit_transform(CRP_df)
CRP_df = pd.DataFrame(imputed, columns=CRP_df.columns)

# %%
# mean, median, and mode for glucose after knn imputation
CRP_df.glucose.mean(),CRP_df.glucose.median(),CRP_df.glucose.mode()
# Out:
# (82.07203539823007,
#  78.05,
#  0    75.0
#  Name: glucose, dtype: float64)

# %% [markdown]
# **After KNN imputation, there is no massive change in the values of mean. And the values of median and mode remain the same.**

# %%
CRP_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3390 entries, 0 to 3389
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3390 non-null   float64
#  1   age                3390 non-null   float64
#  2   education          3390 non-null   float64
#  3   sex                3390 non-null   float64
#  4   is_smoking         3390 non-null   float64
#  5   cigs_per_day       3390 non-null   float64
#  6   bp_meds            3390 non-null   float64
#  7   prevalent_stroke   3390 non-null   float64
#  8   prevalent_hyp      3390 non-null   float64
#  9   diabetes           3390 non-null   float64
#  10  total_cholesterol  3390 non-null   float64
#  11  systolic_bp        3390 non-null   float64
#  12  diastolic_bp       3390 non-null   float64
#  13  bmi                3390 non-null   float64
#  14  heart_rate         3390 non-null   float64
#  15  glucose            3390 non-null   float64
#  16  ten_year_chd       3390 non-null   float64
# dtypes: float64(17)
# memory usage: 450.4 KB

# %% [markdown]
# The KNN imputer has converted all the columns to the float64 datatype. Hence, changing the column datatype accordingly as per the kind of data stored in the respective column.

# %%
# changing datatypes
CRP_df = CRP_df.astype({'age': int, 'education':int,'sex':int,'is_smoking':int,'cigs_per_day':int,
               'bp_meds':int,'prevalent_stroke':int,'prevalent_hyp':int,'diabetes':int,
               'total_cholesterol':float,'systolic_bp':float,'diastolic_bp':float,
               'bmi':float,'heart_rate':float,'glucose':float,'ten_year_chd':int})

# %%
# checking for missing values
CRP_df.isna().sum()
# Out:
# id                   0
# age                  0
# education            0
# sex                  0
# is_smoking           0
# cigs_per_day         0
# bp_meds              0
# prevalent_stroke     0
# prevalent_hyp        0
# diabetes             0
# total_cholesterol    0
# systolic_bp          0
# diastolic_bp         0
# bmi                  0
# heart_rate           0
# glucose              0
# ten_year_chd         0
# dtype: int64

# %% [markdown]
# We have successfully handled all the missing values in the dataset.**bold text**

# %% [markdown]
# # **9. Exploratory Data Analysis:**

# %% [markdown]
# **9.1. Distribution of the dependent variable:**

# %%
# Distribution of dependent varaible - ten_year_chd
plt.figure(figsize=(5,4))
sns.countplot(CRP_df[dependent_var[0]])
plt.xlabel(dependent_var[0])
plt.title(dependent_var[0]+' distribution')
# Out:
# Text(0.5, 1.0, 'ten_year_chd distribution')

# %% [markdown]
# **The dependent variable - 10 year risk of CHD is unbalanced.**

# %%
# Distribution of dependent variable
CRP_df[dependent_var].value_counts()
# Out:
# ten_year_chd
# 0               2879
# 1                511
# dtype: int64

# %%
# unbalanced distribution
511/(2879+511)
# Out:
# 0.15073746312684366

# %% [markdown]
# *The dependent variable - 10-year risk of coronary heart disease is unbalanced. Only ~15% of the patients in the study were eventually exposed to the risk of this heart disease, rest of the patients were not exposed to this disease after the end of 10 year study.*

# %% [markdown]
# # **9.2. Analyzing the distribution of the continuous independent variables:**

# %%
# Analysing the distribution of continuous variables in the dataset
for col in continuous_var:
  plt.figure(figsize=(10,5))
  sns.distplot(CRP_df[col])
  plt.axvline(CRP_df[col].mean(), color='cyan', linestyle='dashed', linewidth=2)
  plt.axvline(CRP_df[col].median(), color='black', linestyle='dashed', linewidth=2)
  plt.title(col+' distribution')
  plt.show()

# %% [markdown]
# **The distribution of several features is skewed, and contains outliers. We'll deal with the skew afterwards.**

# %% [markdown]
# **9.3. Analyzing the distribution of the discrete independent variables:**

# %%
# Analysing the distribution of categorical variables in the dataset
for i in categorical_var:
  plt.figure(figsize=(4,5))
  p = sns.countplot(CRP_df[i])
  plt.xlabel(i)
  plt.title(i+' distribution')
  for i in p.patches:
    p.annotate(f'{i.get_height()}', (i.get_x() + i.get_width() / 2., i.get_height()), ha = 'center', va = 'center', xytext = (0, 12), textcoords = 'offset points')
  plt.show()

# %% [markdown]
# **Summary:**
#
# Majority of the patients belong to the education level 1, followed by 2, 3, and 4 respectively.
#
# There are more female patients compared to male patients.
#
# Almost half the patients are smokers.
#
# 100 patients under the study are undertaking blood pressure medication.
#
# 22 patients under the study have experienced a stroke.
#
# 1069 patients have hypertension.
#
# 87 patients have diabetes.

# %% [markdown]
# **9.4. Analyzing the relationship between the dependent variable and the continuous variables in the data:**

# %%
# Relationship between the dependent variable and continuous independent variables
for i in continuous_var:
  plt.figure(figsize=(10,5))
  sns.catplot(x=dependent_var[0],y=i,data=CRP_df,kind='violin')
  plt.ylabel(i)
  plt.xlabel(dependent_var[0])
  plt.title(dependent_var[0]+' vs '+i)
  plt.show()

# %% [markdown]
# **Summary:**
#
# **The risk of CHD is higher for older patients than younger patients.**
#
# No conclusive evidence on the risk of CHD with other continuous variables

# %% [markdown]
# # **9.5. Analyzing the relationship between the dependent variable and the discrete variables in the data:**

# %%
# Analyzing the relationship between the dependent variable and categorical independent variables
for i in categorical_var:
  plt.figure(figsize=(8,5))
  sns.histplot(x=i, hue=dependent_var[0], data=CRP_df, stat="count", multiple="stack")
  plt.title('Risk of CHD by: '+i)
  # plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left',title=i)
  plt.show()

# %% [markdown]
# ## 9.6. Correlation analysis:

# %%
# Correlation magnitude
plt.figure(figsize=(10,8))
plt.title('Correlation Analysis')
correlation = CRP_df[continuous_var].corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')
# Out:
# <Axes: title={'center': 'Correlation Analysis'}>

# %% [markdown]
# Above is the correlation magnitude heatmap for all the continuous variables in the dataset.
#
# The variables systolic BP and diastolic BP are highly correlated.

# %% [markdown]
# # 9.7. Handling Multicollinearity:

# %%
# Range of systolic bp and diastolic bp

print(CRP_df['systolic_bp'].min(),CRP_df['systolic_bp'].max())
print(CRP_df['diastolic_bp'].min(),CRP_df['diastolic_bp'].max())
# Out:
# 83.5 295.0
# 48.0 142.5

# %% [markdown]
# To handle multicollinearity between these two independent continuous variables, we can replace these two columns with a new variable 'pulse pressure', which is given as follows:
#
# ***Pulse Pressure = Systolic BP - Diastolic BP***

# %% [markdown]
# From the above resource, we also found that:
#
# The normal pulse pressure is around 40 mmHg
#
# Pulse pressures of 50 mmHg or more can increase the risk of heart disease, heart rhythm disorders, stroke and more.
#
# Higher pulse pressures are also thought to play a role in eye and kidney damage from diseases like diabetes.
#
# Low pulse pressure - is where the pulse pressure is one-fourth or less of the systolic blood pressure.
#
# This happens when your heart isn’t pumping enough blood, which is seen in heart failure and certain heart valve diseases. It also happens when a person has been injured and lost a lot of blood or is bleeding internally.

# %%
# Creating a new column pulse_pressure
# and dropping systolic_bp and diastolic_bp

CRP_df['pulse_pressure'] = CRP_df['systolic_bp']-CRP_df['diastolic_bp']
CRP_df.drop('systolic_bp',axis=1,inplace=True)
CRP_df.drop('diastolic_bp',axis=1,inplace=True)

# %%
# columns
CRP_df.columns
# Out:
# Index(['id', 'age', 'education', 'sex', 'is_smoking', 'cigs_per_day',
#        'bp_meds', 'prevalent_stroke', 'prevalent_hyp', 'diabetes',
#        'total_cholesterol', 'bmi', 'heart_rate', 'glucose', 'ten_year_chd',
#        'pulse_pressure'],
#       dtype='object')

# %%
# Updating the continuous_var list

continuous_var.remove('systolic_bp')
continuous_var.remove('diastolic_bp')
continuous_var.append('pulse_pressure')

# %%
# Analyzing the distribution of pulse_pressure
plt.figure(figsize=(8,5))
sns.distplot(CRP_df['pulse_pressure'])
plt.axvline(CRP_df['pulse_pressure'].mean(), color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(CRP_df['pulse_pressure'].median(), color='black', linestyle='dashed', linewidth=2)
plt.title('Pulse Pressure Distribution')
# Out:
# Text(0.5, 1.0, 'Pulse Pressure Distribution')

# %% [markdown]
# The pulse pressures are positively **skewed**

# %%
# Relationship between pulse pressure with the dependent variable
plt.figure(figsize=(8,5))
sns.catplot(x=dependent_var[0],y='pulse_pressure',data=CRP_df,kind='violin')
plt.title('ten_year_chd vs pulse_pressure')
plt.show()

# %% [markdown]
# **On average, the patients with higher pulse pressure are exposed to the coronary heart disease over the period of 10 years.**

# %%
# Updated correlations
plt.figure(figsize=(10,5))
plt.title('Correlation Analysis')
correlation = CRP_df[continuous_var].corr()
sns.heatmap(abs(correlation), annot=True, cmap='coolwarm')
# Out:
# <Axes: title={'center': 'Correlation Analysis'}>

# %% [markdown]
# **We were successful in handling multicollinearity amongst the continuous variables in the dataset.**

# %% [markdown]
# # **10. Feature Selection:**

# %% [markdown]
# **10.1. Discrete feature selection:**

# %% [markdown]
# To check whether discrete variables are related, chi2 test can be used. We define:
#
# 1.Null Hypothesis (H0): Two variables are independent.
#
# 2.Alternate Hypothesis (H1): Two variables are not independent.

# %% [markdown]
# We can use Chi2 test to get a p-value and check if a categorical variable is dependent or independent to the dependent variable. If the p value obtained is greater than 0.05 then we reject the null hypothesis, and accept the alternate hypothesis.

# %%
# chi2 scores
chi_scores = chi2(CRP_df[categorical_var],CRP_df[dependent_var])
chi_scores
# Out:
# (array([ 4.76184162, 13.77838959,  1.98522603, 25.10243827, 15.8619983 ,
#         64.37770831, 35.50630598]),
#  array([2.90973990e-02, 2.05688680e-04, 1.58840936e-01, 5.43640748e-07,
#         6.81331780e-05, 1.02713702e-15, 2.54226209e-09]))

# %%
# P values for discrete features
p_values = pd.Series(chi_scores[1],index = CRP_df[categorical_var].columns)
p_values.sort_values(ascending = False , inplace = True)
p_values
# Out:
# is_smoking          1.588409e-01
# education           2.909740e-02
# sex                 2.056887e-04
# prevalent_stroke    6.813318e-05
# bp_meds             5.436407e-07
# diabetes            2.542262e-09
# prevalent_hyp       1.027137e-15
# dtype: float64

# %%
# Plotting p values for chi2 test for discrete features
plt.figure(figsize=(10,5))
plt.xscale('log')
plt.xlabel('P-value')
plt.title('P-value for discrete features')
p_values.plot.barh()
# Out:
# <Axes: title={'center': 'P-value for discrete features'}>

# %% [markdown]
# Since prevalent hypertension column (prevalent_hyp) has the smallest p value, we can say that it is the most important feature (among the categorical independent variables) which determines the outcome of the dependent variable.
#
# The is_smoking feature has the highest p-value, which indicates that it is the least important feature (among categorical independent variables).
#
# We can drop this column since we already have a column cigs_per_day, which gives the number of cigarettes smoked by the patient in a day. The patients who don't smoke have entered zero in this column.

# %%
# dropping is_smoking
CRP_df.drop('is_smoking',axis=1,inplace=True)

# %%
# dropping is smoking 
categorical_var.remove('is_smoking')
categorical_var
# Out:
# ['education',
#  'sex',
#  'bp_meds',
#  'prevalent_stroke',
#  'prevalent_hyp',
#  'diabetes']

# %% [markdown]
# # **10.2. Outlier analysis:**

# %%
# checking for outliers in continuous features
for col in continuous_var:
  plt.figure(figsize=(8,5))
  sns.boxplot(y = col,x = dependent_var[0],data=CRP_df)
  plt.title(col+' boxplot')
  plt.show()

# %% [markdown]
# There are outliers in the data, the effect of the outliers can be reduced to some extent by transforming it.
#
# Once the data is transformed, if outliers beyond 3 standard deviations from the mean still remain, then they can be imputed with its respective median value.
#
# This is done on the train data only to prevent data leakage.

# %% [markdown]
# # **10.3. Transforming continuous variables to reduce skew:**

# %%
# skewness along the index axis
(CRP_df[continuous_var]).skew(axis = 0)
# Out:
# age                  0.225796
# cigs_per_day         1.204077
# total_cholesterol    0.948170
# bmi                  1.025551
# heart_rate           0.676660
# glucose              6.342892
# pulse_pressure       1.412382
# dtype: float64

# %% [markdown]
# **Many continuous variables are skewed. By log transformation, we aim to reduce the magnitude of skew in these variables to a certain extent.**

# %%
# Skew for log10 transformation
np.log10(CRP_df[continuous_var]+1).skew(axis = 0)
# Out:
# age                 -0.015053
# cigs_per_day         0.275072
# total_cholesterol    0.011860
# bmi                  0.370422
# heart_rate           0.165898
# glucose              2.309072
# pulse_pressure       0.354174
# dtype: float64

# %% [markdown]
# **We can clearly see that by log transformation of the continuous variables, we are able to reduce it's skew to some extent.**

# %%
# Implementing log transformation on continuous variables

CRP_df['age']                   = np.log10(CRP_df['age']+1)
CRP_df['cigs_per_day']          = np.log10(CRP_df['cigs_per_day']+1)
CRP_df['total_cholesterol']     = np.log10(CRP_df['total_cholesterol']+1)
CRP_df['bmi']                   = np.log10(CRP_df['bmi']+1)
CRP_df['heart_rate']            = np.log10(CRP_df['heart_rate']+1)
CRP_df['glucose']               = np.log10(CRP_df['glucose']+1)
CRP_df['pulse_pressure']        = np.log10(CRP_df['pulse_pressure']+1)

# %%
# Checking skew after log transformation
CRP_df[continuous_var].skew(axis = 0)
# Out:
# age                 -0.015053
# cigs_per_day         0.275072
# total_cholesterol    0.011860
# bmi                  0.370422
# heart_rate           0.165898
# glucose              2.309072
# pulse_pressure       0.354174
# dtype: float64

# %% [markdown]
# # **10.4. Analyzing the distribution of transformed features:**

# %%
# Analysing the distribution of continuous varaibles after transformation
for col in continuous_var:
  plt.figure(figsize=(8,5))
  sns.distplot(CRP_df[col])
  plt.axvline(CRP_df[col].mean(), color='cyan', linestyle='dashed', linewidth=2)
  plt.axvline(CRP_df[col].median(), color='black', linestyle='dashed', linewidth=2)
  plt.title(col+' distribution')
  plt.show()

# %% [markdown]
# **Except cigs_per_day, we have successfully been able to reduce the skewness in the continuous variables. Now these distributions are closer to symmetric distribution.**

# %% [markdown]
# ### **10.5. Checking for outliers in transformed features:**

# %%
# checking for outliers in log transformed features
for col in continuous_var:
  plt.figure(figsize=(10,5))
  sns.boxplot(y = col,x = dependent_var[0],data=CRP_df)
  plt.title(col+' boxplot')
  plt.show()

# %% [markdown]
# Except for age and cigs_per_day columns, rest of the numerical columns contain outliers even after log transformation.
#
# To handle this, we can impute the outliers beyond 3 standard deviations from the mean with its median value on the train data.

# %% [markdown]
# # **11. Data Preprocessing:**

# %%
# Defining dependent and independent variables
X = CRP_df.drop('ten_year_chd',axis=1)
y = CRP_df[dependent_var]

# %% [markdown]
# ## **11.1. Choice of prediction model:**

# %% [markdown]
# We are working on binary classification problem.
#
# Here we can start with a simple model, as a baseline model, which is interpretable, ie, Logistic Regression.
#
# Try other standard binary classification models like K nearest neighbors, Naive Bayes, decision tree classifier, and support vector machines.
#
# Use ensemble models, with hyperparameter tuning to check whether they give better predictions.

# %% [markdown]
# # **11.2. Evaluation metrics:**

# %% [markdown]
# Since the data we are dealing with is unbalanced, accuracy may not be the best evaluation metric to evaluate the model performance.
#
# Also, since we are dealing with data related to healthcare, False Negatives are of higher concern than False Positive,
#
# In other words, it doesn’t matter whether we raise a false alarm but the actual positive cases should not go undetected
#
# Considering these points in mind, it is decided that we use Recall as the model evaluation metric.

# %% [markdown]
# ### Recall = TP/(TP+FN)

# %%
# function to get recall score
def recall(actual,predicted):
  '''
  recall(actual,predicted)
  '''
  return recall_score(y_true=actual, y_pred=predicted, average='binary')

# %% [markdown]
# # **11.3. Train Test Split:**

# %% [markdown]
# Since we are working with limited amount of data, ie, around 3390 records, 30% of the records are set aside for testing, 70% for training.
#
# Since the data is imbalanced, stratified split was employed to get almost equal proportion of dependent variables in the train and test sets.

# %%
# train test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0, stratify=y, shuffle=True)

# %%
# Checking the train distribution of dependent variable
y_train.value_counts()
# Out:
# ten_year_chd
# 0               2015
# 1                358
# dtype: int64

# %%
# Proportion of positive outcomes in train dataset
358/(358+2015)
# Out:
# 0.15086388537715972

# %%
# Checking the test distribution of dependent variable
y_test.value_counts()
# Out:
# ten_year_chd
# 0               864
# 1               153
# dtype: int64

# %%
# Proportion of positive outcomes in test dataset
153/(153+864)
# Out:
# 0.1504424778761062

# %% [markdown]
# **The train and test set contain almost equal proportion of results.**

# %% [markdown]
# # **11.4. Handling outliers in the train data:**

# %%
# imputing the outliers beyond 3 standard deviations from the mean with its median value
for i in ['total_cholesterol', 'bmi', 'heart_rate', 'glucose','pulse_pressure']:
  upper_lim = X_train[i].mean() + 3 * X_train[i].std()
  lower_lim = X_train[i].mean() - 3 * X_train[i].std()
  X_train.loc[(X_train[i] > upper_lim),i] = X_train[i].median()
  X_train.loc[(X_train[i] < lower_lim),i] = X_train[i].median()

# %%
X_train[continuous_var].skew(axis = 0)
# Out:
# age                 -0.035936
# cigs_per_day         0.297586
# total_cholesterol   -0.046628
# bmi                  0.215412
# heart_rate           0.074472
# glucose              0.393506
# pulse_pressure       0.270388
# dtype: float64

# %% [markdown]
# **We were successsful in handling outliers in the train data, and thereby reducing skew.**

# %% [markdown]
# # **11.5. Oversampling:**

# %% [markdown]
# Since we are dealing with unbalanced data, ie, only ~15% of the patients were diagnosed with coronary heart disease, we oversample the train dataset using SMOTE (Synthetic Minority Oversampling Technique).
#
# This ensures that the model has trained equally on all kinds of results, and it is not biased to one particular result.

# %%
# visualize the target variable before SMOTE
y_train.value_counts().plot(kind='bar', title='Target variable before SMOTE')
# Out:
# <Axes: title={'center': 'Target variable before SMOTE'}, xlabel='ten_year_chd'>

# %%
# Oversampling using SMOTE
smote = SMOTE()

# fit predictor and target variable
X_smote, y_smote = smote.fit_resample(X_train, y_train)

print('Samples in the original dataset', len(y_train))
print('Samples in the resampled dataset', len(y_smote))
# Out:
# Samples in the original dataset 2373
# Samples in the resampled dataset 4030

# %%
# visualize the target variable after SMOTE
y_smote.value_counts().plot(kind='bar', title='Target variable after SMOTE')
# Out:
# <Axes: title={'center': 'Target variable after SMOTE'}, xlabel='ten_year_chd'>

# %% [markdown]
# **We have successfully oversampled the minority class using SMOTE. Now the model we build will be able to learn from both the classes without any bias.**

# %% [markdown]
# # 11.6. Scaling the data:

# %% [markdown]
# Since the predictions from the distance based models will get affected if the attributes are in different ranges, we need to scale them.
#
# We can use StandardScaler to scale down the variables.
#
# The results obtained from scaling can be stored and used while building those models.
#
# Tree algorithms do not necessarily require scaling.

# %%
# Scaling data
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_smote_scaled = scaler.fit_transform(X_smote)
X_test_scaled = scaler.transform(X_test)

# Converting array to dataframe
X_train_scaled = pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_smote_scaled = pd.DataFrame(X_smote_scaled,columns=X_smote.columns)
X_test_scaled = pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
# Scaled train values
X_train_scaled.head()
# Out:
#          id       age  education       sex  cigs_per_day   bp_meds  \
# 0  0.421853  1.352753   1.042877  1.126340      1.152968 -0.178155
# 1 -1.533156  0.238381  -0.929033  1.126340      1.418967 -0.178155
# 2 -1.404176  0.872536  -0.929033  1.126340      1.152968 -0.178155
# 3 -1.045673  1.444209  -0.929033 -0.887831     -0.926396 -0.178155
# 4  0.239047  0.457551  -0.929033 -0.887831      1.152968 -0.178155
#
#    prevalent_stroke  prevalent_hyp  diabetes  total_cholesterol       bmi  \
# 0         -0.087426      -0.685091 -0.171759           0.279319 -0.546622
# 1         -0.087426      -0.685091 -0.171759           0.165020  0.828332
# 2         -0.087426      -0.685091 -0.171759           0.714396  0.670299
# 3         -0.087426       1.459660 -0.171759           2.429594  0.459589
# 4         -0.087426      -0.685091 -0.171759           0.211021 -1.740096
#
#    heart_rate   glucose  pulse_pressure
# 0   -0.267146 -0.522470        0.021221
# 1   -0.454995 -1.079272       -0.058061
# 2   -0.175143  1.525800       -0.392623
# 3    0.841085  1.718543        1.281191
# 4   -0.454995 -0.434080        0.021221

# %%
# scaled SMOTE values
X_smote_scaled.head()
# Out:
#          id       age  education       sex  cigs_per_day   bp_meds  \
# 0  0.389841  1.241284   1.321922  1.323908      1.197103 -0.140488
# 1 -1.567671  0.039650  -0.815428  1.323908      1.482336 -0.140488
# 2 -1.438526  0.723463  -0.815428  1.323908      1.197103 -0.140488
# 3 -1.079564  1.339901  -0.815428 -0.755340     -1.032622 -0.140488
# 4  0.206801  0.275983  -0.815428 -0.755340      1.197103 -0.140488
#
#    prevalent_stroke  prevalent_hyp  diabetes  total_cholesterol       bmi  \
# 0         -0.070622      -0.645384 -0.145013           0.211949 -0.641329
# 1         -0.070622      -0.645384 -0.145013           0.087946  0.815408
# 2         -0.070622      -0.645384 -0.145013           0.683963  0.647976
# 3         -0.070622       1.549466 -0.145013           2.544777  0.424733
# 4         -0.070622      -0.645384 -0.145013           0.137853 -1.905791
#
#    heart_rate   glucose  pulse_pressure
# 0   -0.303408 -0.602225       -0.152166
# 1   -0.504247 -1.183478       -0.234299
# 2   -0.205042  1.535989       -0.580892
# 3    0.881460  1.737195        1.153114
# 4   -0.504247 -0.509955       -0.152166

# %%
# scaled test values
X_test_scaled.head()
# Out:
#          id       age  education       sex  cigs_per_day   bp_meds  \
# 0 -0.876186 -1.761834   0.253247  1.323908      1.197103 -0.140488
# 1 -0.527393 -0.728094   2.390597  1.323908      0.279614 -0.140488
# 2 -0.609761 -1.448665   0.253247 -0.755340     -1.032622 -0.140488
# 3 -0.319948 -0.332463  -0.815428 -0.755340     -1.032622 -0.140488
# 4  1.282670 -0.865727   0.253247 -0.755340      1.482336 -0.140488
#
#    prevalent_stroke  prevalent_hyp  diabetes  total_cholesterol       bmi  \
# 0         -0.070622       1.549466 -0.145013           0.405204  0.807992
# 1         -0.070622       1.549466 -0.145013          -0.246908  0.930632
# 2         -0.070622      -0.645384 -0.145013          -1.476382 -1.395032
# 3         -0.070622      -0.645384 -0.145013           0.993708  0.471479
# 4         -0.070622      -0.645384 -0.145013           0.211949 -0.323169
#
#    heart_rate   glucose  pulse_pressure
# 0    0.448412 -1.600215       -0.766196
# 1   -1.842780  0.430824        0.973385
# 2   -0.504247 -0.066313       -0.360764
# 3   -0.303408 -0.240349        0.379731
# 4   -1.142580  0.019080       -0.447361

# %% [markdown]
# **We have successfully scaled down the variables using standard scaler.**

# %% [markdown]
# ## **12. ML Model Implementation:**

# %% [markdown]
# **12.1. Logistic Regression**

# %%
# Fitting model
lr_model = LogisticRegression()

# %%
# training the model
lr_model.fit(X_smote_scaled, y_smote)
# Out:
# LogisticRegression()

# %%
# Train predictions
lr_train_pred = lr_model.predict(X_smote_scaled)

# %%
# training set recall
lr_train_recall = recall(y_smote,lr_train_pred)
lr_train_recall
# Out:
# 0.7156327543424318

# %%
# Test predictions
lr_test_pred = lr_model.predict(X_test_scaled)

# %%
# Test recall
lr_test_recall = recall(y_test,lr_test_pred)
lr_test_recall
# Out:
# 0.5751633986928104

# %%
# Classification report
print(classification_report(y_test,lr_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.67      0.76       864
#            1       0.23      0.58      0.33       153
#
#     accuracy                           0.65      1017
#    macro avg       0.57      0.62      0.55      1017
# weighted avg       0.80      0.65      0.70      1017

# %%
# Confusion matrix
from sklearn.metrics import confusion_matrix as cm
from sklearn.metrics import ConfusionMatrixDisplay as cmd
lr_confusion_matrix = cm(y_test, lr_test_pred)
cm_display = cmd(confusion_matrix = lr_confusion_matrix, display_labels = [False, True])

font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 18}
plt.rc('font', **font)

cm_display.plot(cmap='Oranges')
plt.title('Confusion matrix: LOGISTIC REGRESSION')
plt.show()

# %% [markdown]
# **False negatives obtained after using logistic regression: 65**

# %% [markdown]
# # **12.2. K Nearest Neighbors:**

# %%
# Value of k taken upto sqrt(n)
# Where n is no of records in the train dataset
# sqrt(4030) = 63.48
knn_test_res = []
knn_train_res = []
for k in range(1,65):
  knn_model = KNeighborsClassifier(n_neighbors=k)
  knn_model.fit(X_smote_scaled, y_smote)
  knn_train_pred = knn_model.predict(X_smote_scaled)
  knn_train_recall = recall(y_smote,knn_train_pred)
  knn_test_pred = knn_model.predict(X_test_scaled)
  knn_test_recall = recall(y_test,knn_test_pred)
  knn_test_res.append(knn_test_recall)
  knn_train_res.append(knn_train_recall)

# %%
# Plotting the train and test recalls for different values of k
plt.figure(figsize=(8,5))
x_ = range(1,65)
y1 = knn_train_res
y2 = knn_test_res
plt.plot(x_, y1, label='Train Recall')
plt.plot(x_, y2, label = 'Test Recall')
plt.xlabel('K')
plt.ylabel('Recall')
plt.legend()
plt.show()

# %%
# Best k is where the test recall is the highest
best_k = knn_test_res.index(max(knn_test_res))+1
best_k
# Out:
# 61

# %%
# building knn model with best parameters
knn_model = KNeighborsClassifier(n_neighbors=best_k)

# %%
# training the model
knn_model.fit(X_smote_scaled, y_smote)
# Out:
# KNeighborsClassifier(n_neighbors=61)

# %%
# Train predictions
knn_train_pred = knn_model.predict(X_smote_scaled)

# %%
# training set recall
knn_train_recall = recall(y_smote,knn_train_pred)
knn_train_recall
# Out:
# 0.8570719602977668

# %%
# Test predictions
knn_test_pred = knn_model.predict(X_test_scaled)

# %%
# Test recall
knn_test_recall = recall(y_test,knn_test_pred)
knn_test_recall
# Out:
# 0.5882352941176471

# %%
# Classification report
print(classification_report(y_test,knn_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.56      0.68       864
#            1       0.19      0.59      0.29       153
#
#     accuracy                           0.56      1017
#    macro avg       0.54      0.57      0.48      1017
# weighted avg       0.78      0.56      0.62      1017

# %%
# Confusion matrix
knn_confusion_matrix = cm(y_test, knn_test_pred)
cm_display = cmd(confusion_matrix = knn_confusion_matrix, display_labels = [False, True])

font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 18}
plt.rc('font', **font)

cm_display.plot(cmap='Oranges')
plt.title('Confusion matrix: K NEAREST NEIGHBORS')
plt.show()

# %% [markdown]
# **False negatives obtained after using KNN: 65**

# %% [markdown]
# # **12.3. Naive Bayes:**

# %%
# Using stratified k fold cross validation so that each split 
# has almost equal proportion of classification results
cv_method = RepeatedStratifiedKFold(n_splits=4,
                                    n_repeats=3, 
                                    random_state=0)

# %%
# Fitting model
nb_model = GaussianNB()

# %%
# Max depth of dt without hyperparameter tuning = 28 and min samples leaf = 1
nb_model = GaussianNB()
nb_params = {'var_smoothing': np.logspace(0,-9, num=100)
             }

# %%
nb_gridsearch = GridSearchCV(nb_model,
                             nb_params,
                             cv=cv_method,
                             scoring= 'recall')
nb_gridsearch.fit(X_smote_scaled,y_smote)
nb_best_params = nb_gridsearch.best_params_

# %%
# model best parameters
nb_best_params
# Out:
# {'var_smoothing': 1.0}

# %%
# building knn model with best parameters
nb_model = GaussianNB(var_smoothing=nb_best_params['var_smoothing'])

# %%
# training the model
nb_model.fit(X_smote_scaled, y_smote)
# Out:
# GaussianNB(var_smoothing=1.0)

# %%
# Train predictions
nb_train_pred = nb_model.predict(X_smote_scaled)

# %%
# training set recall
nb_train_recall = recall(y_smote,nb_train_pred)
nb_train_recall
# Out:
# 0.8933002481389578

# %%
# Test predictions
nb_test_pred = nb_model.predict(X_test_scaled)

# %%
# Test recall
nb_test_recall = recall(y_test,nb_test_pred)
nb_test_recall
# Out:
# 0.6862745098039216

# %%
# Classification report
print(classification_report(y_test,nb_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.45      0.60       864
#            1       0.18      0.69      0.29       153
#
#     accuracy                           0.48      1017
#    macro avg       0.54      0.57      0.44      1017
# weighted avg       0.78      0.48      0.55      1017

# %%
# Confusion matrix
nb_confusion_matrix = cm(y_test, nb_test_pred)
cm_display = cmd(confusion_matrix = nb_confusion_matrix, display_labels = [False, True])

font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 18}
plt.rc('font', **font)

cm_display.plot(cmap='Oranges')
plt.title('Confusion matrix: NAIVE BAYES')
plt.show()

# %% [markdown]
# **False negatives obtained after using Naive Bayes: 55**

# %% [markdown]
# # **12.4. Decision tree:**

# %%
# Max depth of dt without hyperparameter tuning = 28 and min samples leaf = 1
dt_model = DecisionTreeClassifier()
dt_params = {'max_depth':np.arange(1,10),
             'min_samples_split':np.arange(0.1,1,0.1),
             'min_samples_leaf':np.arange(0.1,0.6,0.1)
             }

# %%
# using gridsearchcv to find best parameters
dt_gridsearch = GridSearchCV(dt_model,
                             dt_params,
                             cv=cv_method,
                             scoring= 'recall')
dt_gridsearch.fit(X_smote,y_smote)
dt_best_params = dt_gridsearch.best_params_

# %%
# model best parameters
dt_best_params
# Out:
# {'max_depth': 1, 'min_samples_leaf': 0.1, 'min_samples_split': 0.1}

# %%
# building knn model with best parameters
dt_model = DecisionTreeClassifier(max_depth=dt_best_params['max_depth'],
                                  min_samples_split=dt_best_params['min_samples_split'],
                                  min_samples_leaf=dt_best_params['min_samples_leaf'])

# %%
# training the model 
dt_model.fit(X_smote_scaled, y_smote)
# Out:
# DecisionTreeClassifier(max_depth=1, min_samples_leaf=0.1, min_samples_split=0.1)

# %%
# Train predictions
dt_train_pred = dt_model.predict(X_smote_scaled)

# %%
# training set recall
dt_train_recall = recall(y_smote,dt_train_pred)
dt_train_recall
# Out:
# 0.8486352357320099

# %%
# Test predictions
dt_test_pred = dt_model.predict(X_test_scaled)

# %%
# Test recall
dt_test_recall = recall(y_test,dt_test_pred)
dt_test_recall
# Out:
# 0.7712418300653595

# %%
# Classification report
print(classification_report(y_test,dt_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.47      0.62       864
#            1       0.21      0.77      0.32       153
#
#     accuracy                           0.52      1017
#    macro avg       0.56      0.62      0.47      1017
# weighted avg       0.81      0.52      0.58      1017

# %%
# Feature importances

dt_feat_imp = pd.Series(dt_model.feature_importances_, index=X.columns)
plt.figure(figsize=(8,5))
plt.title('Feature Importances: DECISION TREE')
plt.xlabel('Relative Importance')
dt_feat_imp.nlargest(20).plot(kind='barh')
# Out:
# <Axes: title={'center': 'Feature Importances: DECISION TREE'}>

# %% [markdown]
# **Only one feature (age) was given imporatance while fitting a decision tree model. This is because of max depth being 1.**

# %%
# Confusion matrix
dt_confusion_matrix = cm(y_test, dt_test_pred)
cm_display = cmd(confusion_matrix = dt_confusion_matrix, display_labels = [False, True])

font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 18}
plt.rc('font', **font)

cm_display.plot(cmap='Oranges')
plt.title('Confusion matrix: DECISION TREE')
plt.show()

# %% [markdown]
# False negatives obtained after using decision tree: 35

# %% [markdown]
# # **12.5. Support Vector Machines:**

# %%
# SVM model parameters
svm_model = SVC()
svm_params = {'C': [0.1, 1, 10],
              'gamma': [0.01, 0.001, 0.0001],
              'kernel': ['rbf']
             }

# %%
# Using gridsearchcv to find best parameters
svm_gridsearch = GridSearchCV(svm_model,
                              svm_params,
                              cv=cv_method,
                              scoring= 'recall')
svm_gridsearch.fit(X_smote_scaled,y_smote)
svm_best_params = svm_gridsearch.best_params_

# %%
# model best parameters
svm_best_params
# Out:
# {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}

# %%
# building knn model with best parameters
svm_model = SVC(C=svm_best_params['C'],
                gamma=svm_best_params['gamma'],
                kernel=svm_best_params['kernel']
                )

# %%
# training the model 
svm_model.fit(X_smote_scaled, y_smote)
# Out:
# SVC(C=10, gamma=0.01)

# %%
# Train predictions
svm_train_pred = svm_model.predict(X_smote_scaled)

# %%
# training set recall
svm_train_recall = recall(y_smote,svm_train_pred)
svm_train_recall
# Out:
# 0.8024813895781637

# %%
# Test predictions
svm_test_pred = svm_model.predict(X_test_scaled)

# %%
# Test recall
svm_test_recall = recall(y_test,svm_test_pred)
svm_test_recall
# Out:
# 0.42483660130718953

# %%
# Classification report
print(classification_report(y_test,svm_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.69      0.77       864
#            1       0.20      0.42      0.27       153
#
#     accuracy                           0.65      1017
#    macro avg       0.53      0.56      0.52      1017
# weighted avg       0.77      0.65      0.70      1017

# %%
# Confusion matrix
svm_confusion_matrix = cm(y_test, svm_test_pred)
cm_display = cmd(confusion_matrix = svm_confusion_matrix, display_labels = [False, True])

font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 18}
plt.rc('font', **font)

cm_display.plot(cmap='Oranges')
plt.title('Confusion matrix: SUPPORT VECTOR MACHINES')
plt.show()

# %% [markdown]
# False negatives obtained after using SVM: 88

# %%
# XGBOOST model
xgb_model = xgb.XGBClassifier(random_state=0)
xgb_params = {'n_estimators':[500],                    # limited due to computational power availability
             'max_depth':[1],
             'min_samples_split':np.arange(0.1,1,0.1),
             'min_samples_leaf':np.arange(0.1,0.6,0.1)}

# %%
# using gridsearchcv to find best parameters
xgb_gridsearch = GridSearchCV(xgb_model,xgb_params,cv=cv_method,scoring='recall')
xgb_gridsearch.fit(X_smote_scaled,y_smote)
xgb_best_params = xgb_gridsearch.best_params_
# Out:
# [12:07:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:25] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:43] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:44] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:46] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:46] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:52] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:07:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:25] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:30] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:30] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:31] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:38] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:39] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:39] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:41] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:42] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:42] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:43] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:44] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:44] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:08:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:25] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:09:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:22] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:25] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:30] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:32] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:42] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:52] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:10:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:33] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:33] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:34] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:38] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:39] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:39] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:41] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:42] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:42] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:43] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:48] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:49] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:49] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:11:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:16] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:17] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:17] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:18] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:18] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:22] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:25] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:38] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:46] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:46] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:48] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:48] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:49] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:52] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:12:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:22] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:30] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:30] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:31] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:32] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:32] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:33] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:33] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:34] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:38] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:44] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:46] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:46] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:48] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:49] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:49] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:13:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:16] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:17] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:22] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:25] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:25] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:30] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:33] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:33] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:34] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:34] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:38] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:38] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:39] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:41] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:41] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:42] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:46] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:48] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:48] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:49] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:52] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:52] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:14:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:11] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:12] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:16] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:16] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:17] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:17] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:18] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:24] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:25] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:30] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:31] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:32] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:37] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:38] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:39] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:41] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:42] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:43] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:43] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:44] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:48] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:49] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:49] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:50] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:52] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:52] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:15:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:02] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:07] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:08] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:09] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:10] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:13] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:14] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:15] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:16] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:16] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:17] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:18] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:19] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:20] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:21] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:22] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:23] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:26] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:27] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:28] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:29] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:30] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:31] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:32] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:33] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:34] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:35] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:36] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:38] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:39] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:40] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:41] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:41] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:42] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:42] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:43] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:44] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:44] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:45] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:46] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:47] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:48] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:51] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:52] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:52] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:53] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:54] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:55] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:56] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:57] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:58] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:16:59] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:17:00] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:17:01] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:17:03] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:17:04] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:17:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:17:05] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.
#
# [12:17:06] WARNING: ../src/learner.cc:767:
# Parameters: { "min_samples_leaf", "min_samples_split" } are not used.

# %%
# best parameters for xgboost classifier
xgb_best_params
# Out:
# {'max_depth': 1,
#  'min_samples_leaf': 0.1,
#  'min_samples_split': 0.1,
#  'n_estimators': 500}

# %%
# Fitting xgb with best parameters
xgb_model = xgb.XGBClassifier(n_estimators=xgb_best_params['n_estimators'],
                                  min_samples_leaf=xgb_best_params['min_samples_leaf'],
                                  min_samples_split=xgb_best_params['min_samples_split'],
                                  max_depth=xgb_best_params['max_depth'],
                                  random_state=0)

# %%
# fit
xgb_model.fit(X_smote_scaled,y_smote)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=0, ...)

# %%
# train predictions
xgb_train_pred = xgb_model.predict(X_smote_scaled)
xgb_train_pred = [round(value) for value in xgb_train_pred]

# %%
# train recall
xgb_train_recall = recall(y_smote,xgb_train_pred)
xgb_train_recall
# Out:
# 0.9975186104218362

# %%
# Test predictions
xgb_test_pred = xgb_model.predict(X_test_scaled)
xgb_test_pred = [round(value) for value in xgb_test_pred]

# %%
# test recall
xgb_test_recall = recall(y_test,xgb_test_pred)
xgb_test_recall
# Out:
# 0.13725490196078433

# %%
# Classification report
print(classification_report(y_test,xgb_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89       864
#            1       0.22      0.14      0.17       153
#
#     accuracy                           0.80      1017
#    macro avg       0.54      0.53      0.53      1017
# weighted avg       0.76      0.80      0.78      1017

# %%
import matplotlib.pyplot as plt

xgb_feat_imp = pd.Series(xgb_model.feature_importances_, index=X.columns)
plt.figure(figsize=(10,5))
plt.title('Feature Importances: XGBoost')
plt.xlabel('Relative Importance')
xgb_feat_imp.nlargest(20).plot(kind='barh')
plt.show()

# %% [markdown]
# Age in the most important feature in deciding the outcome of the variables for XG boost.
#
# Multiple features are given importance here rather than just one feature in case of decision tree.

# %%
print(classification_report(y_test,xgb_test_pred,target_names=['Negative','Positive']))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.86      0.92      0.89       864
#     Positive       0.22      0.14      0.17       153
#
#     accuracy                           0.80      1017
#    macro avg       0.54      0.53      0.53      1017
# weighted avg       0.76      0.80      0.78      1017

# %%
# Confusion matrix
xgb_confusion_matrix = cm(y_test, xgb_test_pred)
cm_display = cmd(confusion_matrix = xgb_confusion_matrix, display_labels = [False, True])

font = {'family' : 'DejaVu Sans',
        'weight' : 'bold',
        'size'   : 22}
plt.rc('font', **font)

cm_display.plot(cmap='Oranges')
plt.title('Confusion matrix: XG BOOST')
plt.show()

# %% [markdown]
# **False negatives obtained after using XG Boost: 108**

# %% [markdown]
# # **13. Results:**

# %% [markdown]
# The train and test recall scores obtained for different models built are as follows:

# %%
# Summarizing the results obtained
from prettytable import PrettyTable
test = PrettyTable(['Sl. No.','Classification Model', 'Train Recall (%)','Test Recall (%)'])
test.add_row(['1','Logistic Regression',lr_train_recall*100,lr_test_recall*100])
test.add_row(['2','K Nearest Neighbors',knn_train_recall*100,knn_test_recall*100])
test.add_row(['3','Naive Bayes',nb_train_recall*100,nb_test_recall*100])
test.add_row(['4','Decision Tree',dt_train_recall*100,dt_test_recall*100])
test.add_row(['5','Support Vector Machines',svm_train_recall*100,svm_test_recall*100])
test.add_row(['6','XG Boost',xgb_train_recall*100,xgb_test_recall*100])
print(test)
# Out:
# +---------+-------------------------+-------------------+--------------------+
# | Sl. No. |   Classification Model  |  Train Recall (%) |  Test Recall (%)   |
# +---------+-------------------------+-------------------+--------------------+
# |    1    |   Logistic Regression   | 71.56327543424318 | 57.51633986928104  |
# |    2    |   K Nearest Neighbors   | 85.70719602977668 | 58.82352941176471  |
# |    3    |       Naive Bayes       | 89.33002481389578 | 68.62745098039215  |
# |    4    |      Decision Tree      |  84.863523573201  | 77.12418300653596  |
# |    5    | Support Vector Machines | 80.24813895781637 | 42.48366013071895  |
# |    6    |         XG Boost        | 99.75186104218362 | 13.725490196078432 |
# +---------+-------------------------+-------------------+--------------------+

# %%
# Plotting Recall scores

ML_models = ['Logistic Regression','K Nearest Neighbors','Naive Bayes','Decision Tree','Support Vector Machines','XG Boost']
train_recalls = [lr_train_recall,knn_train_recall,nb_train_recall,dt_train_recall,svm_train_recall,xgb_train_recall]
test_recalls = [lr_test_recall,knn_test_recall,nb_test_recall,dt_test_recall,svm_test_recall,xgb_test_recall]
  
X_axis = np.arange(len(ML_models))

plt.figure(figsize=(10,5))
plt.barh(X_axis - 0.2, train_recalls, 0.4, label = 'Train Recall')
plt.barh(X_axis + 0.2, test_recalls, 0.4, label = 'Test Recall')
  
plt.yticks(X_axis,ML_models)
plt.xlabel("Recall score")
plt.title("Recall score for each model")
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left',title='Legend')
plt.show()

# %% [markdown]
# **The decision tree has the highest train and test recall score compared to other models built.**

# %% [markdown]
# # **14. Summary and Conclusions:**

# %% [markdown]
# We trained 7 Machine Learning models using the training dataset, and hyperparameter tuning was used in some models to improve the model performance.
#
# To build the models, missing values were handled, feature engineering and feature selection was performed, and the training dataset was oversampled using SMOTE to reduce bias on one outcome.
#
# Recall was chosen as the model evaluation metric because it was very important that we reduce the false negatives.
#
# Initial set of predictions were obtained using the baseline model, ie, logistic regression model, and other commonly used classification models were also build in search of better predictions.
#
# Predicting the risk of coronary heart disease is critical for reducing fatalities caused by this illness. We can avert deaths by taking the required medications and precautions if we can foresee the danger of this sickness ahead of time.
#
# It is critical that the model we develop has a high recall score. It is OK if the model incorrectly identifies a healthy patient as a high risk patient because it will not result in death, but if a high risk patient is incorrectly labelled as healthy, it may result in fatality.
#
# We were able to create a model with a recall of just 0.77 because of limitated data available and limited computational power availabe.
#
# A recall score of 0.77 indicates that out of 100 individuals with the illness, our model will be able to classify only 77 as high risk patients, while the remaining 33 will be misclassified.
#
# Future developments must include a strategy to improve the model recall score, enabling us to save even more lives from this disease. This includes involving more people in the study, and include people with different medical history, etc build an application with better recall score.
#
# From our analysis, it is also found that the age of a person was the most important feature in determining the risk of a patient getting infected with CHD, followed by pulse pressure, prevalent hypertension and total cholesterol.
#
# Diabetes, prevalent stroke and BP medication were the least important features in determining the risk of CHD.
